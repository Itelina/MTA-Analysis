# %% [markdown]
# #MTA Subway Traffic Analysis

# %% [markdown]
# For this analysis I looked into MTA turnstile data for the month of April from 2015.

# %%
execfile('ChallengesSubmission.py')

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
trafficSummary(timeperiod='Mornings', values = 'EXITS')
# Out:
#      TimePeriod                  StationLine    EXITS     ByWeek
# 1510   Mornings        42 ST-GRD CNTRL 4567S  1747519  436879.75
# 1501   Mornings      34 ST-HERALD SQ BDFMNQR  1090612  272653.00
# 1518   Mornings           47-50 ST-ROCK BDFM   996877  249219.25
# 1808   Mornings                   PATH WTC 1   989755  247438.75
# 1439   Mornings       14 ST-UNION SQ LNQR456   756067  189016.75
# 1513   Mornings   42 ST-TIMES SQ 1237ACENQRS   741093  185273.25
# 1761   Mornings          LEXINGTON-53 ST EM6   659094  164773.50
# 1504   Mornings           34 ST-PENN STA ACE   620286  155071.50
# 1532   Mornings                 59 ST 456NQR   616320  154080.00
# 1704   Mornings           FULTON ST 2345ACJZ   599745  149936.25
# 1535   Mornings         59 ST-COLUMBUS ABCD1   568475  142118.75
# 1509   Mornings        42 ST-BRYANT PK BDFM7   517141  129285.25
# 1520   Mornings               5 AVE-53 ST EM   502425  125606.25
# 1562   Mornings                    86 ST 456   500625  125156.25
# 1512   Mornings  42 ST-PA BUS TE ACENQRS1237   451136  112784.00
# 1636   Mornings              CANAL ST JNQRZ6   450233  112558.25
# 1864   Mornings       W 4 ST-WASH SQ ABCDEFM   440949  110237.25
# 1867   Mornings                   WALL ST 23   404541  101135.25
# 1619   Mornings             BOWLING GREEN 45   397528   99382.00
# 1552   Mornings                      77 ST 6   354584   88646.00

# %%
trafficSummaryPlot(timeperiod='Mornings', values = 'EXITS')

# %%
trafficSummary(timeperiod='Lunch', values = 'EXITS')
# Out:
#      TimePeriod                  StationLine   EXITS     ByWeek
# 1041      Lunch        42 ST-GRD CNTRL 4567S  625467  156366.75
# 1033      Lunch      34 ST-HERALD SQ BDFMNQR  602316  150579.00
# 1035      Lunch           34 ST-PENN STA ACE  416369  104092.25
# 1043      Lunch   42 ST-TIMES SQ 1237ACENQRS  413565  103391.25
# 971       Lunch       14 ST-UNION SQ LNQR456  384513   96128.25
# 1090      Lunch                    86 ST 456  340627   85156.75
# 1060      Lunch                 59 ST 456NQR  278781   69695.25
# 1063      Lunch         59 ST-COLUMBUS ABCD1  268200   67050.00
# 1393      Lunch       W 4 ST-WASH SQ ABCDEFM  263781   65945.25
# 1048      Lunch           47-50 ST-ROCK BDFM  260777   65194.25
# 1042      Lunch  42 ST-PA BUS TE ACENQRS1237  240803   60200.75
# 1296      Lunch                    MAIN ST 7  239127   59781.75
# 1097      Lunch                    96 ST 123  233845   58461.25
# 1165      Lunch              CANAL ST JNQRZ6  228176   57044.00
# 970       Lunch       14 ST-UNION SQ 456LNQR  225311   56327.75
# 1076      Lunch                    72 ST 123  220026   55006.50
# 1361      Lunch          ROOSEVELT AVE EFMR7  210391   52597.75
# 1233      Lunch           FULTON ST 2345ACJZ  194917   48729.25
# 1034      Lunch           34 ST-PENN STA 123  184264   46066.00
# 1155      Lunch         BROADWAY/LAFAY BDFQ6  180214   45053.50

# %%
trafficSummaryPlot(timeperiod='Lunch', values = 'EXITS')

# %%
trafficSummary(timeperiod='Afternoons', values = 'EXITS')
# Out:
#      TimePeriod                  StationLine   EXITS     ByWeek
# 91   Afternoons      34 ST-HERALD SQ BDFMNQR  788231  197057.75
# 100  Afternoons        42 ST-GRD CNTRL 4567S  732241  183060.25
# 94   Afternoons           34 ST-PENN STA ACE  700141  175035.25
# 102  Afternoons  42 ST-PA BUS TE ACENQRS1237  679951  169987.75
# 93   Afternoons        34 ST-PENN STA 123ACE  578720  144680.00
# 103  Afternoons   42 ST-TIMES SQ 1237ACENQRS  498422  124605.50
# 152  Afternoons                    86 ST 456  487175  121793.75
# 358  Afternoons                    MAIN ST 7  459447  114861.75
# 447  Afternoons           UNION TPK-KEW G EF  413287  103321.75
# 399  Afternoons                   PATH WTC 1  369815   92453.75
# 423  Afternoons          ROOSEVELT AVE EFMR7  367747   91936.75
# 29   Afternoons       14 ST-UNION SQ LNQR456  365337   91334.25
# 92   Afternoons           34 ST-PENN STA 123  365136   91284.00
# 455  Afternoons       W 4 ST-WASH SQ ABCDEFM  323407   80851.75
# 159  Afternoons                    96 ST 123  298782   74695.50
# 327  Afternoons           JAMAICA CENTER EJZ  287119   71779.75
# 125  Afternoons         59 ST-COLUMBUS ABCD1  272944   68236.00
# 195  Afternoons                BEDFORD AVE L  267120   66780.00
# 138  Afternoons                    72 ST 123  260159   65039.75
# 122  Afternoons                 59 ST 456NQR  250071   62517.75

# %%
trafficSummaryPlot(timeperiod='Afternoons', values = 'EXITS')

# %%
trafficSummary(timeperiod='Evenings/Nights', values = 'EXITS')
# Out:
#           TimePeriod                  StationLine   EXITS    ByWeek
# 829  Evenings/Nights                    MAIN ST 7  198980  49745.00
# 563  Evenings/Nights      34 ST-HERALD SQ BDFMNQR  189771  47442.75
# 894  Evenings/Nights          ROOSEVELT AVE EFMR7  175612  43903.00
# 574  Evenings/Nights  42 ST-PA BUS TE ACENQRS1237  162744  40686.00
# 624  Evenings/Nights                    86 ST 456  161924  40481.00
# 572  Evenings/Nights        42 ST-GRD CNTRL 4567S  160519  40129.75
# 575  Evenings/Nights   42 ST-TIMES SQ 1237ACENQRS  151625  37906.25
# 566  Evenings/Nights           34 ST-PENN STA ACE  146931  36732.75
# 667  Evenings/Nights                BEDFORD AVE L  125130  31282.50
# 798  Evenings/Nights           JAMAICA CENTER EJZ  112665  28166.25
# 504  Evenings/Nights                  145 ST ABCD  107874  26968.50
# 631  Evenings/Nights                    96 ST 123  105986  26496.50
# 724  Evenings/Nights           CROWN HTS-UTICA 34   91481  22870.25
# 472  Evenings/Nights                      1 AVE L   86848  21712.00
# 807  Evenings/Nights              JUNCTION BLVD 7   83585  20896.25
# 491  Evenings/Nights                  125 ST ACBD   79974  19993.50
# 709  Evenings/Nights                CHURCH AVE BQ   78036  19509.00
# 730  Evenings/Nights           DITMARS BL-31 S NQ   77776  19444.00
# 766  Evenings/Nights           FULTON ST 2345ACJZ   77063  19265.75
# 926  Evenings/Nights       W 4 ST-WASH SQ ABCDEFM   75131  18782.75

# %%
trafficSummaryPlot(timeperiod='Evenings/Nights', values = 'EXITS')

# %% [markdown]
# One thing we can see from the chart above is that - the PATH WTC station seems to have an abnormally large volume of traffic on Fridays and Saturdays. Is that a general trend? Were there special events on Fridays/Saturtdays? We take a look at the WTC PATH station in detail:

# %%
stationWeeksPlot()
# Out:
# ['PATH WTC']

# %%
stationWeeksPlot(timeperiod = 'Mornings')
# Out:
# ['PATH WTC']

# %% [markdown]
# Looks like the peak is only happening on Friday, during the week of April 13th (week 16). This might be related to the Tribecca Film Festival - which took place around the WTC train station. The subway exits increased from around 50K people, which is the usual traffic volume, to around 200K. In 2014 the Tribecca film festival had about 400K people attending.
